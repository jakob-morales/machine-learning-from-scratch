# %% [markdown]
# <a href="https://colab.research.google.com/github/jakob-morales/machine-learning-from-scratch/blob/main/KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the iris dataset
iris = datasets.load_iris(as_frame = True)

#Separate feature and target variables
X = iris.data
y = iris.target

#Complete DataFrane
df = iris.data

#Change dummy variable to species name
df['Species'] = iris.target.map(dict(zip([0,1,2],iris.target_names)))

#Drop target variable
X = X.drop('Species', axis=1)

def mink_distance (array1, array2, p=2):
  """Computes the Minkowski distance, which allows the user to input 1 for Manhattan distance or 2 for Euclidean distance."""

  distance = sum(abs(ii-i)**p for i, ii in zip(array1, array2))**(1/p)
  return distance

def close_cluster (X, clusters):
  """Find the closest cluster to each data point in a df."""
  closest_cluster = []
  for i in X.to_numpy():
    cluster_compare = []
    #for each k, find the distance betwwen each data point and the randomly generated cluster
    for ii in clusters:
      cluster_compare.append(mink_distance(i,ii, p=2))
    #return the closest cluster to the data point  
    closest_cluster.append(pd.DataFrame(cluster_compare).nsmallest(1, columns=0).index.to_list())
  result = [x[0] for x in closest_cluster]
  return result

cluster_list = []
inertias = []
predictions = []

def kmeans (X, k_clusters, n_init = 10):
  """Creates k clusters."""
  #A number of iterations "n_init" is chosen to find the lowest inertia.
  for x in range(1, n_init):
    #Three random points are selected to act as clusters.
    indices = np.random.choice(range(len(X)), size = k_clusters)
    clusters = np.array(X.iloc[indices])
    #The closest centroid to each respective point in X is found.
    X['cluster'] = close_cluster(X, clusters)
    #The average is found for each cluster. This new average becomes the new cluster centroid.
    new_cluster = X.groupby('cluster').mean().to_numpy()
    #The closest centroid to each respective point in X is found again. 
    #This process repeats until repeating the process does not change cluster assignments.
    while np.mean(X['cluster'] == close_cluster(X, new_cluster)) != 1:
      X['cluster'] = close_cluster(X, new_cluster)
      new_cluster = X.groupby('cluster').mean().to_numpy()

    #Measure inertia.
    variances = []
    for i, x in enumerate(new_cluster):
      sq_differences = []
      for ii, y in enumerate(X):
        sq_differences.append(mink_distance(X.loc[X['cluster']==i].drop('cluster', axis=1).to_numpy()[ii], new_cluster[i], 2)**2)
      variances.append(np.sum(sq_differences))
    inertia = np.sum(variances)

    cluster_list.append(new_cluster)
    inertias.append(inertia)
    predictions.append(X['cluster'])

    #Format to export.
    kmeans = pd.DataFrame([cluster_list, inertias, predictions]).T
    kmeans = kmeans.rename(columns={0:'centroids', 1:'inertia',2:'predictions'})
    kmeans['inertia'] = kmeans['inertia'].astype(float)
    best = kmeans.nsmallest(1,'inertia')
    return best

def map_and_score (column):
  """Maps the random output of kmean cluster values and scores against target variable"""
  score = str(round(max([
      np.mean(df['Species'] == column.map(dict(zip([0,1,2],iris.target_names)))),
      np.mean(df['Species'] == column.map(dict(zip([0,2,1],iris.target_names)))),
      np.mean(df['Species'] == column.map(dict(zip([1,0,2],iris.target_names)))),
      np.mean(df['Species'] == column.map(dict(zip([1,2,0],iris.target_names)))),
      np.mean(df['Species'] == column.map(dict(zip([2,0,1],iris.target_names)))),
      np.mean(df['Species'] == column.map(dict(zip([2,1,0],iris.target_names))))
      ]), 3)*100) + '%'
  return score

#Run sklearn Model
sklearn_km = KMeans(n_clusters=3).fit(X)

#Run scratch model and clean output
km = kmeans(X, 3, 15)
km_results = X[:]
X = X.drop('cluster',axis=1)

#Compare accuracy of out-of-the-box KMeans with scratch kmeans
print("Scratch Model Accuracy: " + str(map_and_score(km_results['cluster'])))
print("sklearn Model Accuracy: " + str(map_and_score(pd.DataFrame(sklearn_km.predict(X))[0])))
# Out:
# Scratch Model Accuracy: 89.3%
# sklearn Model Accuracy: 89.3%

# %%
#Add cluster centers to df
skl_clusters = pd.DataFrame(sklearn_km.cluster_centers_, columns=df.columns[0:4])
scratch_clusters = pd.DataFrame(km.iloc[0,0], columns=df.columns[0:4])
df_clusters = pd.concat([df, skl_clusters]).fillna("sklearn")
df_clusters = pd.concat([df_clusters, scratch_clusters]).fillna("Scratch").reset_index(drop=True)

#Add Jitter
def jitter(values,j):
  """Changes the values slightly to prevent overlap."""
  return values + np.random.normal(j,.01,values.shape)

#Compare Clusters
sns.scatterplot(x=jitter(df_clusters['sepal length (cm)'],0), 
                y=jitter(df_clusters["sepal width (cm)"],0),
                hue=df_clusters['Species'],
                s=75,
                alpha=.7).set(title="Jittered Cluster Centers of sklearn and Scratch KMeans Model Predictions")
# Out:
# [Text(0.5, 1.0, 'Jittered Cluster Centers of sklearn and Scratch KMeans Model Predictions')]

# %%
#Pairplot of predictions
g = sns.pairplot(km_results, hue='cluster')
g.fig.suptitle("Pairplot of Scratch KMeans Classification Predictions on Iris Data", y=1)
# Out:
# Text(0.5, 1, 'Pairplot of Scratch KMeans Classification Predictions on Iris Data')

# %%
#Pairplot of real clusters
g = sns.pairplot(df, hue='Species')
g.fig.suptitle("Pairplot of Iris Petal/Sepal Size by Species", y=1)
# Out:
# Text(0.5, 1, 'Pairplot of Iris Petal/Sepal Size by Species')
